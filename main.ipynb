# %%
from evaluate import evaluate

from os import path
from sklearn.cluster import AffinityPropagation, KMeans, SpectralClustering, AgglomerativeClustering, KMeans
from sklearn.metrics import silhouette_score

import argparse
import gensim
import logging
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import zipfile

# %%
def save_file(df, name):
    out_path = name + "_pred.csv"
    df.to_csv(out_path, sep="\t", encoding="utf-8", index=False)
    return out_path

# %%
def get_vectors(text, model):
    all_words = [word for word in text if word in model]
    word_list = list(set(all_words))
    if len(word_list) >= 1:
        vectors = np.zeros((len(word_list), model.vector_size))
        for i, word in enumerate(word_list):
            vectors[i, :] = model[word]
        context_vectors = np.divide(np.sum(vectors, axis=0), len(word_list))
    else:
        context_vectors = np.zeros(model.vector_size)
    return context_vectors

# %%
def load_rusvectores(path):
    if not os.path.isfile('180.zip'):
        # !wget http://vectors.nlpl.eu/repository/20/180.zip
    if not os.path.isfile('182.zip'):
        # !wget http://vectors.nlpl.eu/repository/20/182.zip
    # Load model
    with zipfile.ZipFile(path, 'r') as archive:
        stream = archive.open('model.bin')
        model = gensim.models.KeyedVectors.load_word2vec_format(stream, binary=True)
    # Initialize
    model.init_sims(replace=True)
    return model

# %%
def optimal_clusters_silhoette(X):
    range_n_clusters = range(2,21)
    silhouette_avg = []
    for n_clusters in range_n_clusters:
        clusterer = KMeans(n_clusters=n_clusters, random_state=10)
        cluster_labels = clusterer.fit_predict(X)
        scor = silhouette_score(X, cluster_labels)
        if scor > 0:
            silhouette_avg.append(scor)
        else:
            silhouette_avg.append(100)
    print(silhouette_avg)
    return np.argmin(silhouette_avg) + 2

# %%
def main(parameters_dict: dict):
    #Load RusVectores model
    vec_model = load_rusvectores(parameters_dict['model'])
    # Load dataset
    data = pd.read_csv(parameters_dict['inputs'], sep="\t", encoding="utf-8")
    #Get vectors for every word
    all_labels = []
    for query in data['word'].unique():
        print(query)
        word_set = data[data['word'] == query]
        matrix = np.empty((word_set.shape[0], vec_model.vector_size))
        for i, line in enumerate(word_set.iterrows()):
            line_context = line[1].context
            if type(line_context) != str:
                con_vectors = np.zeros(vec_model.vector_size)
            else:
                line_words = line_context.split()
                line_words = [w for w in line_words if w != query]
                con_vectors = get_vectors(line_words, vec_model)
            matrix[i, :] = con_vectors
            i += 1
        # Use AffinityPropagation to determine optimal number of clusters
        cluster_algo = AffinityPropagation(
            max_iter = 350,
            convergence_iter = 60,
            preference=parameters_dict['preference'], 
            damping=parameters_dict['damping'], 
            random_state=42
        ).fit(matrix)
        n_iter_first = cluster_algo.n_iter_
        print(n_iter_first)
        nclusters = len(cluster_algo.cluster_centers_indices_)
        if nclusters == 0:
            # If no cluster assign 1
            nclusters = 1
        elif nclusters == word_set.shape[0]:
            # If too much clusters assign some median
            nclusters = 3
        # Recluster second time
        cluster_algo = SpectralClustering(n_clusters=nclusters, n_init=30,
                                        assign_labels='discretize', n_jobs=-1).fit(matrix)
        #cluster_algo = AgglomerativeClustering(n_clusters=nclusters, linkage="complete").fit(matrix)
        if not parameters_dict['testing']:
            clust_num = word_set.gold_sense_id
            print('Number of real clusters:', len(set(clust_num)))
        pred_labels = cluster_algo.labels_.tolist()
        all_labels += pred_labels
        print('Number of predicted clusters', len(set(pred_labels)))
    # Back to dataframe
    data.predict_sense_id = all_labels
    fname = path.splitext(path.basename(parameters_dict['inputs']))[0]
    if parameters_dict['testing']:
        data_test = pd.read_csv(path.dirname(parameters_dict['inputs']) + '/test.csv', sep="\t", encoding="utf-8")
        data_test.predict_sense_id = data.predict_sense_id
        save_file(data_test, fname)
    else:
        res = evaluate(save_file(data, fname))
        print('ARI', res)

# %% [markdown]
# ## Active Dictionary

# %%
args = {
        'inputs':'data/active-dict/train_pos.csv',
        'model':'180.zip', #182.zip,#'ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz',
        'testing': False,
        'preference': -0.65,
        'damping': 0.8
       }
main(args)
# Out:
# дар_NOUN
# 64
# Number of real clusters: 3
# Number of predicted clusters 3
# двигатель_NOUN
# 85
# Number of real clusters: 2
# Number of predicted clusters 4
# двойник_NOUN
# 65
# Number of real clusters: 4
# Number of predicted clusters 3
# дворец_NOUN
# 74
# Number of real clusters: 2
# Number of predicted clusters 4
# девятка_NOUN
# 73
# Number of real clusters: 9
# Number of predicted clusters 7
# дедушка_NOUN
# 69
# Number of real clusters: 2
# Number of predicted clusters 2
# дежурная_ADJ
# 70
# Number of real clusters: 2
# Number of predicted clusters 2
# дежурный_NOUN
# 66
# Number of real clusters: 2
# Number of predicted clusters 2
# декабрист_NOUN
# 94
# Number of real clusters: 2
# Number of predicted clusters 2
# декрет_NOUN
# 78
# Number of real clusters: 2
# Number of predicted clusters 2
# дело_NOUN
# 208
# Number of real clusters: 17
# Number of predicted clusters 19
# демобилизация_NOUN
# 71
# Number of real clusters: 2
# Number of predicted clusters 3
# демократ_NOUN
# 71
# Number of real clusters: 3
# Number of predicted clusters 4
# демонстрация_NOUN
# 78
# Number of real clusters: 5
# Number of predicted clusters 6
# дерево_NOUN
# 77
# Number of real clusters: 3
# Number of predicted clusters 3
# держава_NOUN
# 65
# Number of real clusters: 2
# Number of predicted clusters 3
# дерзость_NOUN
# 78
# Number of real clusters: 7
# Number of predicted clusters 5
# десяток_NOUN
# 78
# Number of real clusters: 9
# Number of predicted clusters 12
# деятель_NOUN
# 72
# Number of real clusters: 2
# Number of predicted clusters 4
# диалог_NOUN
# 79
# Number of real clusters: 2
# Number of predicted clusters 4
# диаметр_NOUN
# 83
# Number of real clusters: 3
# Number of predicted clusters 3
# диплом_NOUN
# 122
# Number of real clusters: 4
# Number of predicted clusters 4
# директор_NOUN
# 67
# Number of real clusters: 2
# Number of predicted clusters 1
# диск_NOUN
# 99
# Number of real clusters: 10
# Number of predicted clusters 5
# дичь_NOUN
# 78
# Number of real clusters: 3
# Number of predicted clusters 5
# длина_NOUN
# 72
# Number of real clusters: 3
# Number of predicted clusters 8
# доброволец_NOUN
# 71
# Number of real clusters: 2
# Number of predicted clusters 4
# добыча_NOUN
# 86
# Number of real clusters: 6
# Number of predicted clusters 12
# доказательство_NOUN
# 70
# Number of real clusters: 3
# Number of predicted clusters 9
# доктор_NOUN
# 70
# Number of real clusters: 2
# Number of predicted clusters 5
# долгота_NOUN
# 66
# Number of real clusters: 2
# Number of predicted clusters 3
# доля_NOUN
# 77
# Number of real clusters: 7
# Number of predicted clusters 5
# дом_NOUN
# 66
# Number of real clusters: 8
# Number of predicted clusters 9
# дорога_NOUN
# 82
# Number of real clusters: 7
# Number of predicted clusters 9
# достижение_NOUN
# 95
# Number of real clusters: 4
# Number of predicted clusters 4
# древесина_NOUN
# 69
# Number of real clusters: 2
# Number of predicted clusters 6
# дупло_NOUN
# 151
# Number of real clusters: 2
# Number of predicted clusters 2
# дура_NOUN
# 70
# Number of real clusters: 3
# Number of predicted clusters 3
# дух_NOUN
# 80
# Number of real clusters: 11
# Number of predicted clusters 10
# дым_NOUN
# 75
# Number of real clusters: 3
# Number of predicted clusters 5
# дымок_NOUN
# 69
# Number of real clusters: 2
# Number of predicted clusters 6
# дыхание_NOUN
# 210
# Number of real clusters: 7
# Number of predicted clusters 16
# дьявол_NOUN
# 69
# Number of real clusters: 4
# Number of predicted clusters 5
# евро_NOUN
# 68
# Number of real clusters: 2
# Number of predicted clusters 3
# езда_NOUN
# 70
# Number of real clusters: 2
# Number of predicted clusters 6
# жаворонок_NOUN
# 90
# Number of real clusters: 2
# Number of predicted clusters 2
# жало_VERB
# 69
# Number of real clusters: 2
# Number of predicted clusters 2
# жертва_NOUN
# 83
# Number of real clusters: 5
# Number of predicted clusters 6
# жестокость_NOUN
# 67
# Number of real clusters: 2
# Number of predicted clusters 5
# жидкость_NOUN
# 79
# Number of real clusters: 2
# Number of predicted clusters 2
# жить_VERB
# 75
# Number of real clusters: 3
# Number of predicted clusters 2
# жилец_NOUN
# 67
# Number of real clusters: 2
# Number of predicted clusters 1
# жир_NOUN
# 71
# Number of real clusters: 2
# Number of predicted clusters 2
# жребий_NOUN
# 78
# Number of real clusters: 2
# Number of predicted clusters 2
# заведение_NOUN
# 72
# Number of real clusters: 3
# Number of predicted clusters 3
# завещание_NOUN
# 69
# Number of real clusters: 2
# Number of predicted clusters 3
# зависимость_NOUN
# 68
# Number of real clusters: 3
# Number of predicted clusters 5
# заголовок_NOUN
# 69
# Number of real clusters: 4
# Number of predicted clusters 3
# заготовка_NOUN
# 72
# Number of real clusters: 4
# Number of predicted clusters 5
# задание_NOUN
# 70
# Number of real clusters: 5
# Number of predicted clusters 7
# задача_NOUN
# 79
# Number of real clusters: 5
# Number of predicted clusters 11
# задержка_NOUN
# 209
# Number of real clusters: 9
# Number of predicted clusters 14
# зажигалка_NOUN
# 79
# Number of real clusters: 2
# Number of predicted clusters 4
# закон_NOUN
# 68
# Number of real clusters: 7
# Number of predicted clusters 8
# закрытие_NOUN
# 71
# Number of real clusters: 8
# Number of predicted clusters 8
# заложник_NOUN
# 70
# Number of real clusters: 2
# Number of predicted clusters 4
# замена_NOUN
# 86
# Number of real clusters: 2
# Number of predicted clusters 3
# западня_NOUN
# 70
# Number of real clusters: 2
# Number of predicted clusters 2
# запятая_VERB
# 67
# Number of real clusters: 2
# Number of predicted clusters 3
# застой_NOUN
# 69
# Number of real clusters: 2
# Number of predicted clusters 5
# затея_NOUN
# 71
# Number of real clusters: 2
# Number of predicted clusters 3
# затишье_NOUN
# 76
# Number of real clusters: 3
# Number of predicted clusters 4
# затмение_NOUN
# 72
# Number of real clusters: 2
# Number of predicted clusters 3
# затруднение_NOUN
# 64
# Number of real clusters: 2
# Number of predicted clusters 2
# захоронение_NOUN
# 78
# Number of real clusters: 4
# Number of predicted clusters 4
# звезда_NOUN
# 72
# Number of real clusters: 4
# Number of predicted clusters 5
# звон_NOUN
# 81
# Number of real clusters: 2
# Number of predicted clusters 4
# зеркало_NOUN
# 72
# Number of real clusters: 3
# Number of predicted clusters 5
# зло_NOUN
# 69
# Number of real clusters: 3
# Number of predicted clusters 4
# злоупотребление_NOUN
# 70
# Number of real clusters: 2
# Number of predicted clusters 3
# знак_NOUN
# 87
# Number of real clusters: 7
# Number of predicted clusters 11
# знамя_NOUN
# 67
# Number of real clusters: 2
# Number of predicted clusters 1
# значение_NOUN
# 67
# Number of real clusters: 4
# Number of predicted clusters 3
# зонт_NOUN
# 68
# Number of real clusters: 2
# Number of predicted clusters 3
# word	ari	count
# дар_NOUN	0.038332	36
# двигатель_NOUN	-0.043046	15
# двойник_NOUN	0.480312	25
# дворец_NOUN	0.548057	13
# девятка_NOUN	0.136282	47
# дедушка_NOUN	-0.046512	9
# дежурная_ADJ	0.063830	12
# дежурный_NOUN	-0.070588	13
# декабрист_NOUN	1.000000	11
# декрет_NOUN	1.000000	12
# дело_NOUN	0.064633	130
# демобилизация_NOUN	0.622038	14
# демократ_NOUN	0.903144	18
# демонстрация_NOUN	0.113435	38
# дерево_NOUN	0.187726	21
# держава_NOUN	-0.056338	15
# дерзость_NOUN	0.020998	37
# десяток_NOUN	0.100042	57
# деятель_NOUN	0.636364	14
# диалог_NOUN	0.409091	14
# диаметр_NOUN	0.340646	18
# диплом_NOUN	0.159562	25
# директор_NOUN	0.000000	11
# диск_NOUN	0.167057	63
# дичь_NOUN	0.215385	18
# длина_NOUN	0.254799	21
# доброволец_NOUN	0.250710	12
# добыча_NOUN	0.261875	35
# доказательство_NOUN	0.067308	24
# доктор_NOUN	0.315130	17
# долгота_NOUN	0.869739	13
# доля_NOUN	0.231131	45
# дом_NOUN	0.156847	38
# дорога_NOUN	0.083387	47
# достижение_NOUN	0.156448	22
# древесина_NOUN	-0.040956	16
# дупло_NOUN	-0.027174	15
# дура_NOUN	0.015843	12
# дух_NOUN	0.083350	77
# дым_NOUN	0.236850	28
# дымок_NOUN	0.253791	18
# дыхание_NOUN	0.305523	56
# дьявол_NOUN	0.083333	22
# евро_NOUN	0.555556	8
# езда_NOUN	-0.071103	14
# жаворонок_NOUN	0.153846	11
# жало_VERB	0.037500	11
# жертва_NOUN	0.205323	37
# жестокость_NOUN	-0.065886	14
# жидкость_NOUN	0.022222	12
# жилец_NOUN	0.000000	16
# жир_NOUN	0.057789	15
# жить_VERB	0.450415	17
# жребий_NOUN	1.000000	15
# заведение_NOUN	1.000000	14
# завещание_NOUN	0.266667	16
# зависимость_NOUN	0.492514	21
# заголовок_NOUN	0.205556	22
# заготовка_NOUN	0.406690	26
# задание_NOUN	0.349581	33
# задача_NOUN	0.175178	36
# задержка_NOUN	0.110480	60
# зажигалка_NOUN	0.446247	13
# закон_NOUN	0.161972	56
# закрытие_NOUN	0.364458	38
# заложник_NOUN	-0.008163	13
# замена_NOUN	-0.066799	18
# западня_NOUN	0.635762	11
# запятая_VERB	0.343434	14
# застой_NOUN	0.065708	13
# затея_NOUN	-0.102902	12
# затишье_NOUN	0.253333	16
# затмение_NOUN	0.626767	12
# затруднение_NOUN	0.504357	15
# захоронение_NOUN	0.271845	22
# звезда_NOUN	0.249390	40
# звон_NOUN	-0.050505	14
# зеркало_NOUN	0.385542	21
# зло_NOUN	0.155599	23
# злоупотребление_NOUN	0.569432	12
# знак_NOUN	0.182708	55
# знамя_NOUN	0.000000	14
# значение_NOUN	0.386793	30
# зонт_NOUN	0.100000	9
# 	0.216502	2073
# ARI 0.21650180600014454

# %%
args = {
        'inputs':'data/active-dict/test_pos.csv',
        'model':'180.zip',#'ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz',
        'testing': True,
        'preference': -0.65,
        'damping': 0.8
       }
main(args)
# Out:
# давление_NOUN
# 69
# Number of predicted clusters 3
# дама_NOUN
# 86
# Number of predicted clusters 2
# данные_NOUN
# 64
# Number of predicted clusters 6
# дата_NOUN
# 72
# Number of predicted clusters 2
# двойка_NOUN
# 62
# Number of predicted clusters 4
# двор_NOUN
# 69
# Number of predicted clusters 4
# дворник_NOUN
# 80
# Number of predicted clusters 1
# девка_NOUN
# 65
# Number of predicted clusters 13
# девочка_NOUN
# 82
# Number of predicted clusters 5
# девушка_NOUN
# 68
# Number of predicted clusters 5
# девчонка_NOUN
# 68
# Number of predicted clusters 7
# дед_NOUN
# 72
# Number of predicted clusters 3
# дезертир_NOUN
# 70
# Number of predicted clusters 3
# действие_NOUN
# 70
# Number of predicted clusters 10
# действительность_NOUN
# 69
# Number of predicted clusters 2
# декларация_NOUN
# 76
# Number of predicted clusters 3
# декорация_NOUN
# 88
# Number of predicted clusters 3
# делегат_NOUN
# 67
# Number of predicted clusters 1
# деление_NOUN
# 96
# Number of predicted clusters 7
# дельфин_NOUN
# 66
# Number of predicted clusters 4
# демократия_NOUN
# 67
# Number of predicted clusters 2
# день_NOUN
# 75
# Number of predicted clusters 20
# деньги_NOUN
# 69
# Number of predicted clusters 3
# деревня_NOUN
# 63
# Number of predicted clusters 5
# десант_NOUN
# 72
# Number of predicted clusters 3
# десерт_NOUN
# 70
# Number of predicted clusters 3
# деталь_NOUN
# 72
# Number of predicted clusters 2
# детектив_NOUN
# 70
# Number of predicted clusters 2
# ребенок_NOUN
# 80
# Number of predicted clusters 3
# деятельность_NOUN
# 64
# Number of predicted clusters 6
# диагональ_NOUN
# 69
# Number of predicted clusters 3
# диво_ADV
# 74
# Number of predicted clusters 2
# диета_NOUN
# 64
# Number of predicted clusters 3
# дикарь_NOUN
# 81
# Number of predicted clusters 3
# диктатор_NOUN
# 80
# Number of predicted clusters 3
# дипломатия_NOUN
# 79
# Number of predicted clusters 3
# дискант_NOUN
# 66
# Number of predicted clusters 4
# дистанция_NOUN
# 66
# Number of predicted clusters 5
# дитя_NOUN
# 68
# Number of predicted clusters 8
# дневник_NOUN
# 80
# Number of predicted clusters 3
# днище_NOUN
# 70
# Number of predicted clusters 4
# дно_NOUN
# 70
# Number of predicted clusters 8
# добро_NOUN
# 79
# Number of predicted clusters 3
# добродетель_NOUN
# 67
# Number of predicted clusters 4
# доверие_NOUN
# 68
# Number of predicted clusters 5
# дождь_NOUN
# 69
# Number of predicted clusters 2
# доза_NOUN
# 70
# Number of predicted clusters 6
# доклад_NOUN
# 76
# Number of predicted clusters 4
# документ_NOUN
# 69
# Number of predicted clusters 9
# долг_NOUN
# 135
# Number of predicted clusters 5
# должник_NOUN
# 70
# Number of predicted clusters 5
# доллар_NOUN
# 85
# Number of predicted clusters 1
# дополнение_NOUN
# 78
# Number of predicted clusters 4
# дорожка_NOUN
# 75
# Number of predicted clusters 2
# досада_NOUN
# 67
# Number of predicted clusters 1
# доска_NOUN
# 70
# Number of predicted clusters 10
# достаток_NOUN
# 67
# Number of predicted clusters 6
# достоинство_NOUN
# 91
# Number of predicted clusters 4
# достояние_NOUN
# 68
# Number of predicted clusters 1
# доступ_NOUN
# 72
# Number of predicted clusters 2
# дочь_NOUN
# 88
# Number of predicted clusters 3
# дощечка_NOUN
# 68
# Number of predicted clusters 2
# драгоценность_NOUN
# 69
# Number of predicted clusters 4
# драма_NOUN
# 86
# Number of predicted clusters 6
# дробь_NOUN
# 73
# Number of predicted clusters 7
# дрова_NOUN
# 74
# Number of predicted clusters 3
# дрожжи_NOUN
# 67
# Number of predicted clusters 1
# дрожь_NOUN
# 67
# Number of predicted clusters 3
# дружба_NOUN
# 88
# Number of predicted clusters 2
# дрянь_NOUN
# 67
# Number of predicted clusters 4
# дуб_NOUN
# 65
# Number of predicted clusters 4
# дубина_NOUN
# 76
# Number of predicted clusters 6
# дуга_NOUN
# 69
# Number of predicted clusters 10
# дурак_NOUN
# 66
# Number of predicted clusters 4
# душа_NOUN
# 79
# Number of predicted clusters 13
# дуэт_NOUN
# 79
# Number of predicted clusters 3
# дыня_NOUN
# 117
# Number of predicted clusters 4
# дыра_NOUN
# 69
# Number of predicted clusters 2
# дядя_NOUN
# 72
# Number of predicted clusters 6
# дятел_VERB
# 74
# Number of predicted clusters 2
# еврей_NOUN
# 70
# Number of predicted clusters 3
# еда_NOUN
# 71
# Number of predicted clusters 2
# единица_NOUN
# 98
# Number of predicted clusters 14
# единство_NOUN
# 71
# Number of predicted clusters 7
# ежевика_NOUN
# 68
# Number of predicted clusters 3
# ель_NOUN
# 68
# Number of predicted clusters 4
# ельник_NOUN
# 66
# Number of predicted clusters 4
# ерунда_NOUN
# 198
# Number of predicted clusters 4
# жадность_NOUN
# 65
# Number of predicted clusters 3
# жажда_NOUN
# 100
# Number of predicted clusters 2
# жалоба_NOUN
# 63
# Number of predicted clusters 2
# жалость_NOUN
# 68
# Number of predicted clusters 3
# жар_NOUN
# 75
# Number of predicted clusters 4
# железо_NOUN
# 66
# Number of predicted clusters 3
# жемчуг_NOUN
# 81
# Number of predicted clusters 7
# жена_NOUN
# 105
# Number of predicted clusters 4
# жених_NOUN
# 66
# Number of predicted clusters 2
# жест_NOUN
# 65
# Number of predicted clusters 3
# жизнь_NOUN
# 68
# Number of predicted clusters 6
# жилка_NOUN
# 78
# Number of predicted clusters 4
# жук_NOUN
# 65
# Number of predicted clusters 3
# журавль_NOUN
# 69
# Number of predicted clusters 2
# журнал_NOUN
# 69
# Number of predicted clusters 5
# жуть_NOUN
# 70
# Number of predicted clusters 4
# забота_NOUN
# 64
# Number of predicted clusters 5
# завеса_NOUN
# 65
# Number of predicted clusters 3
# завивка_NOUN
# 65
# Number of predicted clusters 2
# завиток_NOUN
# 71
# Number of predicted clusters 3
# завоевание_NOUN
# 75
# Number of predicted clusters 6
# завтрак_NOUN
# 64
# Number of predicted clusters 1
# загадка_NOUN
# 71
# Number of predicted clusters 2
# задник_NOUN
# 98
# Number of predicted clusters 3
# зазор_NOUN
# 76
# Number of predicted clusters 3
# заимствование_NOUN
# 70
# Number of predicted clusters 2
# заказ_NOUN
# 72
# Number of predicted clusters 3
# закат_NOUN
# 70
# Number of predicted clusters 6
# закуска_NOUN
# 85
# Number of predicted clusters 2
# зал_NOUN
# 82
# Number of predicted clusters 7
# залог_NOUN
# 69
# Number of predicted clusters 2
# замазка_NOUN
# 73
# Number of predicted clusters 5
# заметка_NOUN
# 70
# Number of predicted clusters 3
# замечание_NOUN
# 70
# Number of predicted clusters 4
# замок_NOUN
# 71
# Number of predicted clusters 7
# занавес_NOUN
# 68
# Number of predicted clusters 1
# занятие_NOUN
# 69
# Number of predicted clusters 4
# запас_NOUN
# 83
# Number of predicted clusters 8
# записка_NOUN
# 65
# Number of predicted clusters 6
# запись_NOUN
# 63
# Number of predicted clusters 5
# заповедь_NOUN
# 64
# Number of predicted clusters 4
# запрос_NOUN
# 68
# Number of predicted clusters 4
# запруда_ADV
# 68
# Number of predicted clusters 2
# запуск_NOUN
# 94
# Number of predicted clusters 5
# заработок_NOUN
# 69
# Number of predicted clusters 1
# заражение_NOUN
# 71
# Number of predicted clusters 3
# зараза_NOUN
# 65
# Number of predicted clusters 2
# зародыш_NOUN
# 90
# Number of predicted clusters 3
# заря_VERB
# 70
# Number of predicted clusters 2
# заряд_NOUN
# 73
# Number of predicted clusters 7
# зарядка_NOUN
# 80
# Number of predicted clusters 7
# засада_NOUN
# 65
# Number of predicted clusters 2
# защита_NOUN
# 98
# Number of predicted clusters 24
# защитник_NOUN
# 69
# Number of predicted clusters 13
# заявка_NOUN
# 76
# Number of predicted clusters 6
# заявление_NOUN
# 75
# Number of predicted clusters 2
# заяц_NOUN
# 66
# Number of predicted clusters 1
# звание_NOUN
# 69
# Number of predicted clusters 6
# звено_NOUN
# 73
# Number of predicted clusters 4
# зверство_NOUN
# 65
# Number of predicted clusters 3
# зверь_NOUN
# 63
# Number of predicted clusters 3
# звонок_NOUN
# 81
# Number of predicted clusters 4
# звук_NOUN
# 71
# Number of predicted clusters 7
# здоровье_NOUN
# 63
# Number of predicted clusters 3
# зелень_NOUN
# 81
# Number of predicted clusters 8
# земля_NOUN
# 83
# Number of predicted clusters 4
# зенит_ADJ
# 79
# Number of predicted clusters 2
# зерно_NOUN
# 72
# Number of predicted clusters 12
# злодей_NOUN
# 66
# Number of predicted clusters 6
# змея_NOUN
# 70
# Number of predicted clusters 2
# знакомство_NOUN
# 70
# Number of predicted clusters 3
# знание_NOUN
# 71
# Number of predicted clusters 3
# значок_NOUN
# 81
# Number of predicted clusters 4
# золото_NOUN
# 66
# Number of predicted clusters 5
# зона_NOUN
# 64
# Number of predicted clusters 4
# зонтик_NOUN
# 73
# Number of predicted clusters 3
# зоология_NOUN
# 183
# Number of predicted clusters 6
# зубр_NOUN
# 71
# Number of predicted clusters 2
# зуд_NOUN
# 108
# Number of predicted clusters 2

# %% [markdown]
# ### BTC-RNC

# %%
args = {
        'inputs':'data/bts-rnc/train_pos.csv',
        'model':'180.zip',#'ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz',
        'testing': False,
        'preference': -0.7,
        'damping': 0.6
       }
main(args)
# Out:
# балка_NOUN
# 67
# Number of real clusters: 2
# Number of predicted clusters 4
# вид_NOUN
# 66
# Number of real clusters: 3
# Number of predicted clusters 2
# винт_NOUN
# 67
# Number of real clusters: 4
# Number of predicted clusters 5
# горн_NOUN
# 67
# Number of real clusters: 3
# Number of predicted clusters 2
# губа_NOUN
# 69
# Number of real clusters: 3
# Number of predicted clusters 4
# жаба_NOUN
# 67
# Number of real clusters: 4
# Number of predicted clusters 4
# клетка_NOUN
# 68
# Number of real clusters: 6
# Number of predicted clusters 4
# крыло_NOUN
# 72
# Number of real clusters: 8
# Number of predicted clusters 4
# купюра_NOUN
# 74
# Number of real clusters: 2
# Number of predicted clusters 3
# курица_NOUN
# 66
# Number of real clusters: 2
# Number of predicted clusters 3
# лавка_NOUN
# 67
# Number of real clusters: 2
# Number of predicted clusters 4
# лайка_NOUN
# 65
# Number of real clusters: 2
# Number of predicted clusters 3
# лев_NOUN
# 65
# Number of real clusters: 4
# Number of predicted clusters 1
# лира_NOUN
# 62
# Number of real clusters: 2
# Number of predicted clusters 2
# мина_NOUN
# 66
# Number of real clusters: 3
# Number of predicted clusters 2
# мишень_NOUN
# 68
# Number of real clusters: 2
# Number of predicted clusters 4
# обед_NOUN
# 68
# Number of real clusters: 4
# Number of predicted clusters 3
# оклад_NOUN
# 70
# Number of real clusters: 3
# Number of predicted clusters 3
# опушка_NOUN
# 68
# Number of real clusters: 2
# Number of predicted clusters 4
# полис_NOUN
# 68
# Number of real clusters: 2
# Number of predicted clusters 2
# пост_NOUN
# 68
# Number of real clusters: 5
# Number of predicted clusters 4
# поток_NOUN
# 68
# Number of real clusters: 2
# Number of predicted clusters 4
# проказа_NOUN
# 68
# Number of real clusters: 2
# Number of predicted clusters 3
# пропасть_NOUN
# 67
# Number of real clusters: 4
# Number of predicted clusters 3
# проспект_NOUN
# 69
# Number of real clusters: 4
# Number of predicted clusters 4
# пытка_NOUN
# 69
# Number of real clusters: 2
# Number of predicted clusters 5
# рысь_NOUN
# 66
# Number of real clusters: 2
# Number of predicted clusters 2
# среда_NOUN
# 69
# Number of real clusters: 4
# Number of predicted clusters 4
# хвост_NOUN
# 69
# Number of real clusters: 4
# Number of predicted clusters 2
# штамп_NOUN
# 68
# Number of real clusters: 4
# Number of predicted clusters 2
# word	ari	count
# балка_NOUN	0.190935	119
# вид_NOUN	0.416978	77
# винт_NOUN	0.229371	123
# горн_NOUN	0.020800	51
# губа_NOUN	0.020014	137
# жаба_NOUN	-0.006246	121
# клетка_NOUN	0.211004	150
# крыло_NOUN	0.090020	91
# купюра_NOUN	-0.001328	150
# курица_NOUN	0.010909	93
# лавка_NOUN	0.062718	149
# лайка_NOUN	0.113067	99
# лев_NOUN	0.000000	44
# лира_NOUN	0.168110	49
# мина_NOUN	0.399058	65
# мишень_NOUN	0.108473	121
# обед_NOUN	0.063021	100
# оклад_NOUN	0.017662	146
# опушка_NOUN	0.006386	148
# полис_NOUN	0.003229	142
# пост_NOUN	0.218408	144
# поток_NOUN	0.020578	136
# проказа_NOUN	0.117824	146
# пропасть_NOUN	0.042324	127
# проспект_NOUN	0.000554	139
# пытка_NOUN	0.019866	143
# рысь_NOUN	0.354484	120
# среда_NOUN	0.270796	144
# хвост_NOUN	0.158170	121
# штамп_NOUN	0.304865	96
# 	0.113020	3491
# ARI 0.11302001219160614

# %%
args = {
        'inputs':'data/bts-rnc/train_pos.csv',
        'model':'182.zip',#'ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz',
        'testing': False,
        'preference': -0.65,
        'damping': 0.8
       }
main(args)
# Out:
# балка_NOUN
# 77
# Number of real clusters: 2
# Number of predicted clusters 2
# вид_NOUN
# 65
# Number of real clusters: 3
# Number of predicted clusters 2
# винт_NOUN
# 107
# Number of real clusters: 4
# Number of predicted clusters 3
# горн_NOUN
# 65
# Number of real clusters: 3
# Number of predicted clusters 1
# губа_NOUN
# 70
# Number of real clusters: 3
# Number of predicted clusters 2
# жаба_NOUN
# 78
# Number of real clusters: 4
# Number of predicted clusters 2
# клетка_NOUN
# 72
# Number of real clusters: 6
# Number of predicted clusters 3
# крыло_NOUN
# 78
# Number of real clusters: 8
# Number of predicted clusters 2
# купюра_NOUN
# 105
# Number of real clusters: 2
# Number of predicted clusters 2
# курица_NOUN
# 70
# Number of real clusters: 2
# Number of predicted clusters 3
# лавка_NOUN
# 65
# Number of real clusters: 2
# Number of predicted clusters 2
# лайка_NOUN
# 70
# Number of real clusters: 2
# Number of predicted clusters 2
# лев_NOUN
# 65
# Number of real clusters: 4
# Number of predicted clusters 1
# лира_NOUN
# 67
# Number of real clusters: 2
# Number of predicted clusters 2
# мина_NOUN
# 66
# Number of real clusters: 3
# Number of predicted clusters 2
# мишень_NOUN
# 95
# Number of real clusters: 2
# Number of predicted clusters 2
# обед_NOUN
# 66
# Number of real clusters: 4
# Number of predicted clusters 2
# оклад_NOUN
# 80
# Number of real clusters: 3
# Number of predicted clusters 2
# опушка_NOUN
# 122
# Number of real clusters: 2
# Number of predicted clusters 3
# полис_NOUN
# 77
# Number of real clusters: 2
# Number of predicted clusters 2
# пост_NOUN
# 74
# Number of real clusters: 5
# Number of predicted clusters 3
# поток_NOUN
# 112
# Number of real clusters: 2
# Number of predicted clusters 4
# проказа_NOUN
# 76
# Number of real clusters: 2
# Number of predicted clusters 2
# пропасть_NOUN
# 87
# Number of real clusters: 4
# Number of predicted clusters 2
# проспект_NOUN
# 75
# Number of real clusters: 4
# Number of predicted clusters 3
# пытка_NOUN
# 73
# Number of real clusters: 2
# Number of predicted clusters 3
# рысь_NOUN
# 72
# Number of real clusters: 2
# Number of predicted clusters 2
# среда_NOUN
# 79
# Number of real clusters: 4
# Number of predicted clusters 3
# хвост_NOUN
# 64
# Number of real clusters: 4
# Number of predicted clusters 2
# штамп_NOUN
# 67
# Number of real clusters: 4
# Number of predicted clusters 2
# word	ari	count
# балка_NOUN	0.018044	119
# вид_NOUN	0.385500	77
# винт_NOUN	0.116130	123
# горн_NOUN	0.000000	51
# губа_NOUN	-0.001403	137
# жаба_NOUN	0.034164	121
# клетка_NOUN	0.350384	150
# крыло_NOUN	0.047957	91
# купюра_NOUN	0.000369	150
# курица_NOUN	0.002137	93
# лавка_NOUN	0.248179	149
# лайка_NOUN	0.056066	99
# лев_NOUN	0.000000	44
# лира_NOUN	0.337425	49
# мина_NOUN	0.114998	65
# мишень_NOUN	0.041873	121
# обед_NOUN	0.000492	100
# оклад_NOUN	-0.014510	146
# опушка_NOUN	0.001037	148
# полис_NOUN	-0.010999	142
# пост_NOUN	0.292637	144
# поток_NOUN	0.036972	136
# проказа_NOUN	0.150549	146
# пропасть_NOUN	0.080436	127
# проспект_NOUN	0.000049	139
# пытка_NOUN	0.044393	143
# рысь_NOUN	0.633133	120
# среда_NOUN	0.277997	144
# хвост_NOUN	0.263979	121
# штамп_NOUN	0.434160	96
# 	0.129105	3491
# ARI 0.12910503768279336

# %%
args = {
        'inputs':'data/bts-rnc/test_pos.csv',
        'model':'182.zip',#'ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz',
        'testing': True,
        'preference': -0.45,
        'damping': 0.8
       }
main(args)
# Out:
# акция_NOUN
# 81
# Number of predicted clusters 4
# баба_NOUN
# 65
# Number of predicted clusters 2
# байка_NOUN
# 67
# Number of predicted clusters 4
# бум_NOUN
# 77
# Number of predicted clusters 2
# бычок_NOUN
# 90
# Number of predicted clusters 3
# вал_VERB
# 75
# Number of predicted clusters 2
# газ_NOUN
# 80
# Number of predicted clusters 4
# гвоздик_NOUN
# 78
# Number of predicted clusters 4
# гипербол_NOUN
# 92
# Number of predicted clusters 3
# град_NOUN
# 81
# Number of predicted clusters 5
# гусеница_NOUN
# 105
# Number of predicted clusters 4
# дождь_NOUN
# 86
# Number of predicted clusters 3
# домино_NOUN
# 77
# Number of predicted clusters 5
# забой_NOUN
# 91
# Number of predicted clusters 3
# икра_NOUN
# 93
# Number of predicted clusters 4
# кабачок_NOUN
# 80
# Number of predicted clusters 5
# капот_NOUN
# 82
# Number of predicted clusters 5
# карьера_NOUN
# 74
# Number of predicted clusters 4
# кличка_NOUN
# 66
# Number of predicted clusters 3
# ключ_NOUN
# 99
# Number of predicted clusters 4
# кок_NOUN
# 65
# Number of predicted clusters 1
# кольцо_NOUN
# 89
# Number of predicted clusters 4
# концерт_NOUN
# 84
# Number of predicted clusters 3
# котелок_NOUN
# 74
# Number of predicted clusters 3
# крона_NOUN
# 75
# Number of predicted clusters 4
# крупа_NOUN
# 89
# Number of predicted clusters 2
# кулак_NOUN
# 82
# Number of predicted clusters 4
# лейка_NOUN
# 79
# Number of predicted clusters 4
# лук_NOUN
# 77
# Number of predicted clusters 3
# мандарин_NOUN
# 75
# Number of predicted clusters 5
# ножка_NOUN
# 82
# Number of predicted clusters 4
# опора_NOUN
# 80
# Number of predicted clusters 5
# патрон_NOUN
# 67
# Number of predicted clusters 3
# печать_NOUN
# 94
# Number of predicted clusters 4
# пол_NOUN
# 68
# Number of predicted clusters 3
# полоз_NOUN
# 78
# Number of predicted clusters 3
# почерк_NOUN
# 74
# Number of predicted clusters 3
# пробка_NOUN
# 81
# Number of predicted clusters 4
# рак_NOUN
# 84
# Number of predicted clusters 4
# рок_NOUN
# 84
# Number of predicted clusters 2
# свет_NOUN
# 136
# Number of predicted clusters 3
# секрет_NOUN
# 74
# Number of predicted clusters 3
# скат_NOUN
# 79
# Number of predicted clusters 4
# слог_NOUN
# 72
# Number of predicted clusters 3
# стан_NOUN
# 79
# Number of predicted clusters 4
# стопка_NOUN
# 71
# Number of predicted clusters 4
# таз_NOUN
# 80
# Number of predicted clusters 4
# такса_NOUN
# 84
# Number of predicted clusters 5
# тюрьма_NOUN
# 105
# Number of predicted clusters 4
# шах_NOUN
# 107
# Number of predicted clusters 3
# шашка_NOUN
# 94
# Number of predicted clusters 4

# %% [markdown]
# ### WIKI-WIKI

# %%
args = {
        'inputs':'data/wiki-wiki/train_pos.csv',
        'model':'182.zip',#'ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz',
        'testing': False,
        'preference': -0.85,
        'damping': 0.9
       }
main(args)
# Out:
# замок_NOUN
# 99
# Number of real clusters: 2
# Number of predicted clusters 3
# лук_NOUN
# 91
# Number of real clusters: 2
# Number of predicted clusters 2
# суд_NOUN
# 108
# Number of real clusters: 2
# Number of predicted clusters 3
# бор_NOUN
# 97
# Number of real clusters: 2
# Number of predicted clusters 2
# word	ari	count
# бор_NOUN	0.925003	56
# замок_NOUN	0.454188	138
# лук_NOUN	0.759285	110
# суд_NOUN	0.478780	135
# 	0.598257	439
# ARI 0.59825666820205

# %%
args = {
        'inputs': 'data/wiki-wiki/test_pos.csv',
        'model': '182.zip',#'ruwikiruscorpora_upos_skipgram_300_2_2018.vec.gz',
        'testing': True,
        'preference': -0.85,
        'damping': 0.9
       }
main(args)
# Out:
# банк_NOUN
# 94
# Number of predicted clusters 3
# белок_NOUN
# 82
# Number of predicted clusters 4
# бит_NOUN
# 83
# Number of predicted clusters 2
# горе_NOUN
# 86
# Number of predicted clusters 1
# граф_NOUN
# 79
# Number of predicted clusters 2
# душа_NOUN
# 88
# Number of predicted clusters 1
